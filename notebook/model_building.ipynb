# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
import io
file_name = list(uploaded.keys())[0]
train_df = pd.read_csv(io.BytesIO(uploaded[file_name]))
# Dataset is now stored in a Pandas Dataframe
# Out:
#      <input type="file" id="files-626ced32-1676-4f6e-8b56-5c156a011de9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-626ced32-1676-4f6e-8b56-5c156a011de9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(train_df)
# Out:
#         price    year manufacturer                     model  condition  \
# 0       30990  2017.0       toyota      tundra double cab sr       good
# 1       15000  2013.0         ford                 f-150 xlt  excellent
# 2       35000  2019.0       toyota                    tacoma  excellent
# 3       29990  2016.0    chevrolet                  colorado       good
# 4       38590  2011.0    chevrolet                  corvette       good
# ...       ...     ...          ...                       ...        ...
# 316480  23590  2019.0       nissan         maxima s sedan 4d       good
# 316481  30590  2020.0        volvo  s60 t5 momentum sedan 4d       good
# 316482  34990  2020.0     cadillac                       xts       good
# 316483  28990  2018.0        lexus           es 350 sedan 4d       good
# 316484  30590  2019.0          bmw  4 series 430i gran coupe       good
#
#           cylinders    fuel  odometer title_status transmission drive  \
# ...

# %%
numeric_variables = ['int8','int16','int32','int64','float16','float32','float64']
categorical_columns = []
features = train_df.columns.values.tolist()
features
# Out:
# ['price',
#  'year',
#  'manufacturer',
#  'model',
#  'condition',
#  'cylinders',
#  'fuel',
#  'odometer',
#  'title_status',
#  'transmission',
#  'drive',
#  'size',
#  'type',
#  'paint_color',
#  'state',
#  'lat',
#  'long']

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
train_data = train_df
for col in features:
  if train_df[col].dtype in numeric_variables:
    continue
  categorical_columns.append(col)

for col in categorical_columns:
  if col in train_df.columns:
    le = LabelEncoder()
    le.fit(list(train_df[col].astype(str).values))
    train_data[col] = le.transform(list(train_df[col].astype(str).values))
train_data
# Out:
#         price    year  manufacturer  model  condition  cylinders  fuel  \
# 0       30990  2017.0            40  17076          2          6     2
# 1       15000  2013.0            13   9072          0          5     2
# 2       35000  2019.0            40  16126          0          5     2
# 3       29990  2016.0             7   7188          2          5     2
# 4       38590  2011.0             7   7449          2          6     2
# ...       ...     ...           ...    ...        ...        ...   ...
# 316480  23590  2019.0            32  12450          2          5     2
# 316481  30590  2020.0            42  15175          2          7     2
# 316482  34990  2020.0             6  18063          2          7     0
# 316483  28990  2018.0            23   8307          2          5     2
# 316484  30590  2019.0             4   1966          2          7     2
#
#         odometer  title_status  transmission  drive  size  type  paint_color  \
# ...

# %%
train_data['year'] = train_data['year'].fillna(0).astype(int)
train_data['odometer'] = train_data['odometer'].fillna(0).astype(int)
train_data['lat'] = train_data['lat'].fillna(0)
train_data['long'] = train_data['long'].fillna(0)
print(train_data)
# Out:
#         price  year  manufacturer  model  condition  cylinders  fuel  \
# 0       30990  2017            40  17076          2          6     2
# 1       15000  2013            13   9072          0          5     2
# 2       35000  2019            40  16126          0          5     2
# 3       29990  2016             7   7188          2          5     2
# 4       38590  2011             7   7449          2          6     2
# ...       ...   ...           ...    ...        ...        ...   ...
# 316480  23590  2019            32  12450          2          5     2
# 316481  30590  2020            42  15175          2          7     2
# 316482  34990  2020             6  18063          2          7     0
# 316483  28990  2018            23   8307          2          5     2
# 316484  30590  2019             4   1966          2          7     2
#
#         odometer  title_status  transmission  drive  size  type  paint_color  \
# ...

# %%
train_data = train_data[train_data['price'] > 1000]
train_data = train_data[train_data['price'] < 40000]
# Rounded ['odometer'] to 5000
train_data['odometer'] = train_data['odometer'] // 5000
train_df = train_df[train_df['year'] > 110]

train_data
# Out:
# <ipython-input-7-55fc22205a57>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['odometer'] = train_data['odometer'] // 5000
#         price  year  manufacturer  model  condition  cylinders  fuel  \
# 0       30990  2017            40  17076          2          6     2
# 1       15000  2013            13   9072          0          5     2
# 2       35000  2019            40  16126          0          5     2
# 3       29990  2016             7   7188          2          5     2
# 4       38590  2011             7   7449          2          6     2
# ...       ...   ...           ...    ...        ...        ...   ...
# 316480  23590  2019            32  12450          2          5     2
# ...

# %%
# prompt: train test split into train_data1, test_data1

from sklearn.model_selection import train_test_split

train_data1, test_data1 = train_test_split(train_data, test_size=0.2, random_state=42)

# %%
x_train = train_data1.drop(columns=['price'])
y_train = train_data1[['price']]
y_train


x_test = test_data1.drop(columns=['price'])
y_test = test_data1[['price']]

# %%
# prompt: code for standardization for train_data

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = pd.DataFrame(scaler.fit_transform(x_train), columns = x_train.columns)



x_test_scaled = pd.DataFrame(scaler.fit_transform(x_test), columns = x_test.columns)

# %%
x_test = test_data1.drop(columns=['price'])
y_test = test_data1[['price']]
x_test
# Out:
#         year  manufacturer  model  condition  cylinders  fuel  odometer  \
# 265952  2004            18  11027          4          7     2        30
# 137500  2010            26  11017          4          5     2        28
# 223632  2013            32  15410          2          7     2        16
# 170520  2020            38  13498          0          7     2         1
# 5798    2012            40  14456          4          3     2         9
# ...      ...           ...    ...        ...        ...   ...       ...
# 12000   2015            13   8652          4          7     2        14
# 216311  2010            16  13369          1          5     2        34
# 278154  2015            24  12770          0          5     2        25
# 155435  2006            13   9085          0          6     2        32
# 237634  2004            13  15971          4          0     2        27
#
#         title_status  transmission  drive  size  type  paint_color  state  \
# ...

# %%
x_test2= scaler.fit_transform(x_test)
x_test2
# Out:
# array([[-0.0278974 , -0.20744551,  0.13022609, ...,  1.22730747,
#         -0.44924422,  0.13937042],
#        [ 0.03598823,  0.45354381,  0.12798977, ..., -0.22730694,
#          0.21348071,  0.80580067],
#        [ 0.06793105,  0.9492858 ,  1.11040537, ...,  0.76447561,
#          0.28504535,  0.49043177],
#        ...,
#        [ 0.08922626,  0.28829648,  0.52001676, ...,  1.29342631,
#         -1.22444231, -0.1353755 ],
#        [-0.00660219, -0.62056383, -0.30406736, ..., -0.09506927,
#          0.625657  ,  0.43821129],
#        [-0.0278974 , -0.62056383,  1.23586295, ...,  0.89671329,
#          1.4346388 , -1.47721829]])

# %% [markdown]
# ## Stochastic Gradient Descent
# Regressors are fitted by stochastic gradient descent under convex loss functions, such as SVMs. Each sample at a time, the gradient of the loss is determined, and the model is updated along the way using a schedule of decreasing strength, or learning rate. The regularizer, which uses either the squared euclidean, L2, absolute, L1, or elastic net, is a penalty imposed to the loss function that reduces model parameters towards the zero vector.

# %%
from sklearn.linear_model import SGDRegressor
import numpy as np
model1 = SGDRegressor()
# Model1 uses squred error for the loss and squared euclidean for regularization
model1.fit(x_train_scaled,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SGDRegressor()

# %%
print(np.isnan(x_train_scaled).sum())
print(np.isnan(y_train).sum())
# Out:
# year            0
# manufacturer    0
# model           0
# condition       0
# cylinders       0
# fuel            0
# odometer        0
# title_status    0
# transmission    0
# drive           0
# size            0
# type            0
# paint_color     0
# state           0
# lat             0
# long            0
# dtype: int64
# price    0
# dtype: int64

# %%
predictions_train = model1.predict(x_train_scaled)

predictions_test = model1.predict(x_test_scaled)
predictions_test
print(predictions_train)

print(predictions_train.shape)
print(y_train.shape)
# Out:
# [11991.18036064 14831.18943686 13276.05661341 ... 15993.65526703
#  12933.79173232 15529.65248793]
# (227079,)
# (227079, 1)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
r2_train = r2_score(y_train, predictions_train)
r2_test = r2_score(y_test, predictions_test)
print(f'R-squared of stochastic gradient descent for train data: {r2_train}')
print(f'R-squared of stochastic gradient descent for test data: {r2_test}')
# Out:
# R-squared of stochastic gradient descent for train data: 0.2321252821644343
# R-squared of stochastic gradient descent for test data: 0.2355980644831952

# %% [markdown]
# ## Random Forest Regressor
# A random forest is a meta estimator that employs averaging to increase the predictive accuracy and control over fitting while fitting several decision tree regressors on different subsamples of the dataset.

# %%
from sklearn.ensemble import RandomForestRegressor
model2 = RandomForestRegressor(bootstrap=True,max_depth=2,random_state=0)
model2.fit(x_train_scaled,y_train)

predictions_train2 = model2.predict(x_train_scaled)
predictions_test2 = model2.predict(x_test_scaled)
predictions_test2
r2_train2 = r2_score(y_train, predictions_train2)
r2_test2 = r2_score(y_test, predictions_test2)
print(f'R-squared of Random forest regressor for train data: {r2_train2}')
print(f'R-squared of Random forest regressor for test data: {r2_test2}')
# Out:
# <ipython-input-18-71aed9b91424>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model2.fit(x_train_scaled,y_train)
# R-squared of Random forest regressor for train data: 0.44581531640075434
# R-squared of Random forest regressor for test data: 0.44903697159869704

# %% [markdown]
# ## Bagging Regressor
# An ensemble meta estimator known as a bagging regressor fits base regressors independently on random subsets of the original dataset, then aggregates each individual estimate to get the final prediction.

# %%
from sklearn.ensemble import BaggingRegressor
from sklearn.svm import SVR
model3 = BaggingRegressor(estimator=SVR(),n_estimators=10,random_state=0)
model3.fit(x_train_scaled,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_bagging.py:508: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return column_or_1d(y, warn=True)

# %%
predictions_train3 = model3.predict(x_train_scaled)
predictions_test3 = model3.predict(x_test_scaled)
predictions_test3
r2_train3 = r2_score(y_train, predictions_train3)
r2_test3 = r2_score(y_test, predictions_test3)
print(f'R-squared of Bagging Regressor for train data: {r2_train3}')
print(f'R-squared of Bagging Regressor for test data: {r2_test3}')
