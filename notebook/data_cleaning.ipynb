# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/craigslist-carstrucks-data/vehicles.csv

# %%
#load dataset
data= pd.read_csv("/kaggle/input/craigslist-carstrucks-data/vehicles.csv")
data.head()
# Out:
#            id                                                url  \
# 0  7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1  7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2  7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3  7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4  7210384030  https://greensboro.craigslist.org/cto/d/trinit...
#
#                    region                         region_url  price  year  \
# 0                prescott    https://prescott.craigslist.org   6000   NaN
# 1            fayetteville       https://fayar.craigslist.org  11900   NaN
# 2            florida keys        https://keys.craigslist.org  21000   NaN
# 3  worcester / central MA   https://worcester.craigslist.org   1500   NaN
# 4              greensboro  https://greensboro.craigslist.org   4900   NaN
#
#   manufacturer model condition cylinders  ... size  type paint_color  \
# ...

# %%
data.shape
# Out:
# (426880, 26)

# %%
data.describe
# Out:
# <bound method NDFrame.describe of                 id                                                url  \
# 0       7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1       7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2       7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3       7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4       7210384030  https://greensboro.craigslist.org/cto/d/trinit...
# ...            ...                                                ...
# 426875  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426876  7301591187  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426877  7301591147  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426878  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426879  7301591129  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#                         region                         region_url  price  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 26 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            426880 non-null  int64
#  1   url           426880 non-null  object
#  2   region        426880 non-null  object
#  3   region_url    426880 non-null  object
#  4   price         426880 non-null  int64
#  5   year          425675 non-null  float64
#  6   manufacturer  409234 non-null  object
#  7   model         421603 non-null  object
#  8   condition     252776 non-null  object
#  9   cylinders     249202 non-null  object
#  10  fuel          423867 non-null  object
#  11  odometer      422480 non-null  float64
#  12  title_status  418638 non-null  object
#  13  transmission  424324 non-null  object
#  14  VIN           265838 non-null  object
#  15  drive         296313 non-null  object
#  16  size          120519 non-null  object
# ...

# %%
data.county
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 426875   NaN
# 426876   NaN
# 426877   NaN
# 426878   NaN
# 426879   NaN
# Name: county, Length: 426880, dtype: float64

# %%
data = data.drop('county', axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 25 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            426880 non-null  int64
#  1   url           426880 non-null  object
#  2   region        426880 non-null  object
#  3   region_url    426880 non-null  object
#  4   price         426880 non-null  int64
#  5   year          425675 non-null  float64
#  6   manufacturer  409234 non-null  object
#  7   model         421603 non-null  object
#  8   condition     252776 non-null  object
#  9   cylinders     249202 non-null  object
#  10  fuel          423867 non-null  object
#  11  odometer      422480 non-null  float64
#  12  title_status  418638 non-null  object
#  13  transmission  424324 non-null  object
#  14  VIN           265838 non-null  object
#  15  drive         296313 non-null  object
#  16  size          120519 non-null  object
# ...

# %%
#train test split (data splited for train and test)
train_x,train_y,test_x,test_y

# %%
unique_values_B = data['title_status'].unique()
print("Unique values in column :", unique_values_B)
# Out:
# Unique values in column : [nan 'clean' 'rebuilt' 'lien' 'salvage' 'missing' 'parts only']

# %%
unique_values_B = data['region'].unique()
print("Unique values in column :", unique_values_B)
# Out:
# Unique values in column : ['prescott' 'fayetteville' 'florida keys' 'worcester / central MA'
#  'greensboro' 'hudson valley' 'medford-ashland' 'erie' 'el paso'
#  'bellingham' 'skagit / island / SJI' 'la crosse' 'auburn' 'birmingham'
#  'dothan' 'florence / muscle shoals' 'gadsden-anniston'
#  'huntsville / decatur' 'mobile' 'montgomery' 'tuscaloosa'
#  'anchorage / mat-su' 'fairbanks' 'kenai peninsula' 'southeast alaska'
#  'flagstaff / sedona' 'mohave county' 'phoenix' 'show low' 'sierra vista'
#  'tucson' 'yuma' 'fort smith' 'jonesboro' 'little rock' 'texarkana'
#  'bakersfield' 'chico' 'fresno / madera' 'gold country' 'hanford-corcoran'
#  'humboldt county' 'imperial county' 'inland empire' 'los angeles'
#  'mendocino county' 'merced' 'modesto' 'monterey bay' 'orange county'
#  'palm springs' 'redding' 'reno / tahoe' 'sacramento' 'san diego'
#  'san luis obispo' 'santa barbara' 'santa maria' 'SF bay area'
#  'siskiyou county' 'stockton' 'susanville' 'ventura county'
# ...

# %% [markdown]
# #working with the features
# * Id doesn't give any more reliable info for the prediticion of data so we are  dropping this.
# * url also doesn't give any more reliable info for the prediticion of data so we are  dropping this.
# * region provides us the information about the cars available in different places.
# * region url is craiglist data, which has url for every region, doesn't give any more reliable info for the prediticion of data so we are  dropping this.
# * price provoides about the appropriate rate of car according to  the specification.
# * year provides about the year when the car was developed.
# * manufacturer : it shows about the car company.
# * model : it descrive the specification of car.
# * condition : it describes the status of the car.
# * cylinder : it shows the number of cylinders available in the car
# * fuel : it illustrates the fuel type of the vechicle (Disel, petrol).
# * odometer : it shows the distance covered by the vechicle.
# * transimission : it shows the type of wheel drive either automatic or manual
# * vin : Vechicle identification number
# * drive : it is the fuction or feature of the car like 4wd, rwd, fwd.
# * size  : provides size of vechicle i.e. compact or suv
# * type  : it is the type of vechicle ('pickup' 'truck' 'other' 'coupe' 'SUV' 'hatchback' 'mini-van' 'sedan''offroad' 'bus' 'van' 'convertible' 'wagon )
# * paint_color: colour of vechicle
# * image_url  : image of vechicle
# * description : Canvas description
# * state  : it is the abbrevation or the short form of the state the vechicle is issued.
# * lat   :latitude degree
# * long  : longoitude degree
# * posting_date: it is the date published about the car advertisement.

# %% [markdown]
# column that should be fired/lay off:::
#
# id , region url, url, vin,image_url,description,lat, long, posting_date,state.

# %% [markdown]
# #unique features  of each column
# * region : It provides us about the city where the vechile is available.
# * price : It is the rate of the car.
# * year : it shows the year when the car was made.
# * manufacturer : it shows about the car company.
# * model : it descrive the specification of car.
# * condition : it describes the status of the car.
# * cylinder : it shows the number of cylinders available in the car
# * fuel : it illustrates the fuel type of the vechicle (Disel, petrol).
# * odometer : it shows the distance covered by the vechicle.
# * transimission : it shows the type of wheel drive either automatic or manual
# * vin : Vechicle identification number
# * drive : it is the fuction or feature of the car like 4wd, rwd, fwd.
# * size  : provides size of vechicle i.e. compact or suv
# * type  : it is the type of vechicle ('pickup' 'truck' 'other' 'coupe' 'SUV' 'hatchback' 'mini-van' 'sedan''offroad' 'bus' 'van' 'convertible' 'wagon )
# * paint_color: colour of vechicle
# * image_url  : image of vechicle
# * description : Canvas description
# * state  : it is the abbrevation or the short form of the state the vechicle is issued.
# * lat   :latitude degree
# * long  : longoitude degree
# * posting_date: it is the date published about the car advertisement.

# %%
unique_values_C = data['manufacturer'].unique()
print("Unique values in column :", unique_values_C)
# Out:
# Unique values in column : [nan 'gmc' 'chevrolet' 'toyota' 'ford' 'jeep' 'nissan' 'ram' 'mazda'
#  'cadillac' 'honda' 'dodge' 'lexus' 'jaguar' 'buick' 'chrysler' 'volvo'
#  'audi' 'infiniti' 'lincoln' 'alfa-romeo' 'subaru' 'acura' 'hyundai'
#  'mercedes-benz' 'bmw' 'mitsubishi' 'volkswagen' 'porsche' 'kia' 'rover'
#  'ferrari' 'mini' 'pontiac' 'fiat' 'tesla' 'saturn' 'mercury'
#  'harley-davidson' 'datsun' 'aston-martin' 'land rover' 'morgan']

# %%
unique_values_C = data['condition'].unique()
print("Unique values in column :", unique_values_C)
# Out:
# Unique values in column : [nan 'good' 'excellent' 'fair' 'like new' 'new' 'salvage']

# %%
unique_values_C = data['model'].unique()
print("Unique values in column :", unique_values_C)
# Out:
# Unique values in column : [nan 'sierra 1500 crew cab slt' 'silverado 1500' ... 'gand wagoneer'
#  '96 Suburban' 'Paige Glenbrook Touring']

# %%
unique_values_C = data['transmission'].unique()
print("Unique values in column :", unique_values_C)
# Out:
# Unique values in column : [nan 'other' 'automatic' 'manual']

# %%
unique_values_D = data['VIN'].unique()
print("Unique values in column :", unique_values_D)
#vechicleidentificationnumber
# Out:
# Unique values in column : [nan '3GTP1VEC4EG551563' '1GCSCSE06AZ123805' ... '2HGES15535H620534'
#  '1FDWF37P64EA24868' 'SAJGX2749VCOO8376']

# %%
unique_values_E = data['drive'].unique()
print("Unique values in column :", unique_values_E)
# Out:
# Unique values in column : [nan 'rwd' '4wd' 'fwd']

# %%
unique_values_B = data['size'].unique()
print("Unique values in column :", unique_values_B)
# Out:
# Unique values in column : [nan 'full-size' 'mid-size' 'compact' 'sub-compact']

# %%
unique_values_B = data['type'].unique()
print("Unique values in column :", unique_values_B)
# Out:
# Unique values in column : [nan 'pickup' 'truck' 'other' 'coupe' 'SUV' 'hatchback' 'mini-van' 'sedan'
#  'offroad' 'bus' 'van' 'convertible' 'wagon']

# %%
unique_values_B = data['paint_color'].unique()
print("Unique values in column :", unique_values_B)
# Out:
# Unique values in column : [nan 'white' 'blue' 'red' 'black' 'silver' 'grey' 'brown' 'yellow'
#  'orange' 'green' 'custom' 'purple']

# %%
unique_values_B = data['image_url'].unique()
print("Unique values in column :", unique_values_B)
# Out:
# Unique values in column : [nan 'https://images.craigslist.org/00R0R_lwWjXSEWNa7z_0x20oM_600x450.jpg'
#  'https://images.craigslist.org/01212_jjirIWa0y02z_0gw0co_600x450.jpg' ...
#  'https://images.craigslist.org/00h0h_hGbhVx97PYZz_0CI0t2_600x450.jpg'
#  'https://images.craigslist.org/00a0a_glcFDSsitmxz_0t20CI_600x450.jpg'
#  'https://images.craigslist.org/00C0C_3D2bgxR1cysz_0ak07K_600x450.jpg']

# %%
unique_values_B = data['description'].unique()
print("Unique values in column :", unique_values_B)
# Out:
# Unique values in column : [nan
# ...

# %%
unique_values_B = data['state'].unique()
print("Unique values in column :", unique_values_B)
# Out:
# Unique values in column : ['az' 'ar' 'fl' 'ma' 'nc' 'ny' 'or' 'pa' 'tx' 'wa' 'wi' 'al' 'ak' 'ca'
#  'co' 'ct' 'dc' 'de' 'ga' 'hi' 'id' 'il' 'in' 'ia' 'ks' 'ky' 'la' 'me'
#  'md' 'mi' 'mn' 'ms' 'mo' 'mt' 'ne' 'nv' 'nj' 'nm' 'nh' 'nd' 'oh' 'ok'
#  'ri' 'sc' 'sd' 'tn' 'ut' 'vt' 'va' 'wv' 'wy']

# %%
unique_values_B = data['long'].unique()
print("Unique values in column :", unique_values_B)
# Out:
# Unique values in column : [        nan  -85.48      -85.5189   ... -106.307144 -105.5449
#  -108.222976]

# %%
unique_values_B = data['lat'].unique()
print("Unique values in column :", unique_values_B)
# Out:
# Unique values in column : [      nan 32.59     32.592    ... 44.3252   40.745625 43.64293 ]

# %%
unique_values_B = data['posting_date'].unique()
print("Unique values in column :", unique_values_B)
# Out:
# Unique values in column : [nan '2021-05-04T12:31:18-0500' '2021-05-04T12:31:08-0500' ...
#  '2021-04-04T03:21:17-0600' '2021-04-04T03:21:11-0600'
#  '2021-04-04T03:21:07-0600']
