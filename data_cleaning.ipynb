# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/cars3.csv')
df.head(25)
# Out:
#     price    year manufacturer                        model  condition  \
# 0   30990  2017.0       toyota         tundra double cab sr       good
# 1   15000  2013.0         ford                    f-150 xlt  excellent
# 2   35000  2019.0       toyota                       tacoma  excellent
# 3   29990  2016.0    chevrolet                     colorado       good
# 4   38590  2011.0    chevrolet                     corvette       good
# 5    4500  1992.0         jeep                     cherokee  excellent
# 6   32990  2017.0         jeep                     wrangler       good
# 7   30990  2016.0    chevrolet                     colorado       good
# 8   27990  2014.0       toyota     tacoma access cab pickup       good
# 9   37990  2016.0    chevrolet                       camaro       good
# 10  33590  2014.0       toyota    tundra crewmax sr5 pickup       good
# 11  30990  2019.0         ford   ranger supercrew xl pickup       good
# ...

# %%
df.shape
# Out:
# (316485, 17)

# %%
df.describe()
# Out:
#               price           year      odometer            lat           long
# count  3.669490e+05  365798.000000  3.648130e+05  363655.000000  363655.000000
# mean   8.564234e+04    2011.272396  9.748862e+04      38.484473     -94.386143
# std    1.313784e+07       9.099166  1.996671e+05       5.867490      18.218454
# min    1.000000e+00    1900.000000  0.000000e+00     -84.122245    -159.827728
# 25%    7.278000e+03    2008.000000  3.727900e+04      34.570000    -111.236250
# 50%    1.500000e+04    2013.000000  8.591600e+04      39.208100     -87.960000
# 75%    2.759000e+04    2017.000000  1.341660e+05      42.370586     -80.790000
# max    3.736929e+09    2022.000000  1.000000e+07      82.390818     173.885502

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366949 entries, 0 to 366948
# Data columns (total 17 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price         366949 non-null  int64
#  1   year          365798 non-null  float64
#  2   manufacturer  350858 non-null  object
#  3   model         362270 non-null  object
#  4   condition     227294 non-null  object
#  5   cylinders     217637 non-null  object
#  6   fuel          364488 non-null  object
#  7   odometer      364813 non-null  float64
#  8   title_status  359511 non-null  object
#  9   transmission  365278 non-null  object
#  10  drive         254187 non-null  object
#  11  size          102298 non-null  object
#  12  type          288666 non-null  object
#  13  paint_color   258644 non-null  object
#  14  state         366949 non-null  object
#  15  lat           363655 non-null  float64
#  16  long          363655 non-null  float64
# ...

# %%
remove_features = ['id','url','region','region_url','image_url','description','posting_date','county','VIN']
df = df.drop(remove_features, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-8aff3839c449> in <cell line: 2>()
#       1 remove_features = ['id','url','region','region_url','image_url','description','posting_date','county','VIN']
# ----> 2 df = df.drop(remove_features, axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366949 entries, 0 to 366948
# Data columns (total 17 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price         366949 non-null  int64
#  1   year          365798 non-null  float64
#  2   manufacturer  350858 non-null  object
#  3   model         362270 non-null  object
#  4   condition     227294 non-null  object
#  5   cylinders     217637 non-null  object
#  6   fuel          364488 non-null  object
#  7   odometer      364813 non-null  float64
#  8   title_status  359511 non-null  object
#  9   transmission  365278 non-null  object
#  10  drive         254187 non-null  object
#  11  size          102298 non-null  object
#  12  type          288666 non-null  object
#  13  paint_color   258644 non-null  object
#  14  state         366949 non-null  object
#  15  lat           363655 non-null  float64
#  16  long          363655 non-null  float64
# ...

# %%
# dealing with missing values

df.isnull().sum()
# Out:
# price                0
# year              1074
# manufacturer     15974
# model             4679
# condition       133208
# cylinders       143673
# fuel              2342
# odometer          2022
# title_status      7124
# transmission      1584
# drive           108687
# size            254054
# type             74238
# paint_color     103489
# state                0
# lat               3189
# long              3189
# dtype: int64

# %%
# prompt: write a code to drop the rows whose price column is 0 or NaN

df = df[df['price'] != 0].dropna(subset=['price'])

# %%
df.isnull().sum()
# Out:
# price                0
# year              1173
# manufacturer     16185
# model             4701
# condition       151389
# cylinders       160410
# fuel              2594
# odometer          2290
# title_status      7734
# transmission      1823
# drive           120254
# size            282933
# type             85932
# paint_color     117149
# state                0
# lat               3489
# long              3489
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 393985 entries, 0 to 426879
# Data columns (total 17 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price         393985 non-null  int64
#  1   year          392812 non-null  float64
#  2   manufacturer  377800 non-null  object
#  3   model         389284 non-null  object
#  4   condition     242596 non-null  object
#  5   cylinders     233575 non-null  object
#  6   fuel          391391 non-null  object
#  7   odometer      391695 non-null  float64
#  8   title_status  386251 non-null  object
#  9   transmission  392162 non-null  object
#  10  drive         273731 non-null  object
#  11  size          111052 non-null  object
#  12  type          308053 non-null  object
#  13  paint_color   276836 non-null  object
#  14  state         393985 non-null  object
#  15  lat           390496 non-null  float64
#  16  long          390496 non-null  float64
# ...

# %%
df.head(50)
# Out:
#     price    year manufacturer                        model  condition  \
# 0    6000     NaN          NaN                          NaN        NaN
# 1   11900     NaN          NaN                          NaN        NaN
# 2   21000     NaN          NaN                          NaN        NaN
# 3    1500     NaN          NaN                          NaN        NaN
# 4    4900     NaN          NaN                          NaN        NaN
# 5    1600     NaN          NaN                          NaN        NaN
# 6    1000     NaN          NaN                          NaN        NaN
# 7   15995     NaN          NaN                          NaN        NaN
# 8    5000     NaN          NaN                          NaN        NaN
# 9    3000     NaN          NaN                          NaN        NaN
# 15  13995     NaN          NaN                          NaN        NaN
# 16  24999     NaN          NaN                          NaN        NaN
# ...

# %%
# prompt: code to remove first 28 rows

df = df.iloc[22:]

# %%
df.head()
# Out:
#     price    year manufacturer                     model  condition  \
# 27  33590  2014.0          gmc  sierra 1500 crew cab slt       good
# 28  22590  2010.0    chevrolet            silverado 1500       good
# 29  39590  2020.0    chevrolet       silverado 1500 crew       good
# 30  30990  2017.0       toyota      tundra double cab sr       good
# 31  15000  2013.0         ford                 f-150 xlt  excellent
#
#       cylinders fuel  odometer title_status transmission drive       size  \
# 27  8 cylinders  gas   57923.0        clean        other   NaN        NaN
# 28  8 cylinders  gas   71229.0        clean        other   NaN        NaN
# 29  8 cylinders  gas   19160.0        clean        other   NaN        NaN
# 30  8 cylinders  gas   41124.0        clean        other   NaN        NaN
# 31  6 cylinders  gas  128000.0        clean    automatic   rwd  full-size
#
#       type paint_color state     lat     long
# 27  pickup       white    al  32.590 -85.4800
# ...

# %%
# prompt: make a list of columns that has object type

object_cols = [col for col in df.columns if df[col].dtype == 'object']
print(object_cols)
# Out:
# ['manufacturer', 'model', 'condition', 'cylinders', 'fuel', 'title_status', 'transmission', 'drive', 'size', 'type', 'paint_color', 'state']

# %%
# prompt: write code to find the uniue values of all the features in the given dataset

for column in object_cols:
  unique_values = df[column].unique()
  print(f"Unique values for column '{column}':")
  for value in unique_values:
    print(f"\t- {value}")
# Out:
# Streaming output truncated to the last 5000 lines.
# 	- rat rod
# 	- f450 diesel powerstroke
# 	- boyertown
# 	- Samurai JLX
# 	- 100 cs quattro wagon
# 	- 5 window
# 	- sportsman trans van
# 	- silverado 3500hd ltz 4
# 	- 100 pick-up truck
# 	- HUDSON Convertible
# 	- olds coupe
# 	- fiesta se 4dr sedan
# 	- mustang gt premium 2dr conv
# 	- civic ex, gas saver, reli
# 	- cargo van nv2500
# 	- sierra 3500hd srw denali
# 	- super duty f-250 srw king
# 	- winstar
# 	- grand marquis limited
# 	- focus 5dr hb se
# 	- escort xz2
# 	- sierra 1500 sle 4x4 4dr exte
# 	- International DT4400
# 	- f-350 super duty crwc
# 	- 5500 crew cab flatbed
# 	- Peterbilt Hino International
# 	- civic hybrid 4dr sedan
# 	- sierra 3500hd sle 4x4 4dr do
# 	- and freightliner
# 	- c-max energi hatchback se
# 	- 2010 Freightliner Cascadia
# 	- PONTAIC
# 	- custom f150 4x4
# 	- crv se awd
# 	- astro.
# 	- International KB-2
# 	- Damon Workhorse
# 	- 1983 Trans Am
# 	- couger
# 	- t campervn
# ...

# %% [markdown]
# Analysis on manufacturer

# %%
# prompt: find the unique values of manufacture column from df dataframe and their frequency

unique_values = df['manufacturer'].unique()
frequency = df['manufacturer'].value_counts()

print("Unique values in 'manufacturer' column:")
for value in unique_values:
  print(f"\t- {value}")

print("\nFrequency of each unique value:")
print(frequency)
# Out:
# Unique values in 'manufacturer' column:
# 	- gmc
# 	- chevrolet
# 	- toyota
# 	- ford
# 	- jeep
# 	- nissan
# 	- ram
# 	- mazda
# 	- cadillac
# 	- honda
# 	- dodge
# 	- lexus
# 	- jaguar
# 	- buick
# 	- chrysler
# 	- volvo
# 	- audi
# 	- infiniti
# 	- lincoln
# 	- alfa-romeo
# 	- subaru
# 	- nan
# 	- acura
# 	- hyundai
# 	- mercedes-benz
# 	- bmw
# 	- mitsubishi
# 	- volkswagen
# 	- porsche
# 	- kia
# 	- rover
# 	- ferrari
# 	- mini
# 	- pontiac
# 	- fiat
# 	- tesla
# 	- saturn
# 	- mercury
# 	- harley-davidson
# 	- datsun
# 	- aston-martin
# 	- land rover
# 	- morgan
#
# Frequency of each unique value:
# ford               64457
# chevrolet          35195
# toyota             31483
# nissan             17373
# honda              17278
# jeep               13865
# bmw                13745
# dodge              12257
# gmc                11604
# mercedes-benz      10411
# subaru              8984
# volkswagen          8708
# hyundai             8629
# ram                 8297
# ...

# %%
# prompt: remove items whose frequency is less than 700 from manufacture column in dataframe df

df = df[df['manufacturer'].isin(df['manufacturer'].value_counts()[df['manufacturer'].value_counts() > 700].index)]

# %% [markdown]
# Analysis on state

# %%
# code to count the total unique values in state column

unique_state_count = df['state'].nunique()
print(f"Total unique values in 'state' column: {unique_state_count}")
# Out:
# Total unique values in 'state' column: 51

# %%
# prompt: count the frequency of unique items in state column

state_counts = df['state'].value_counts()
print(state_counts)
# Out:
# ca    45359
# fl    27315
# tx    21377
# ny    17904
# oh    16649
# mi    16433
# or    14259
# pa    12902
# nc    12697
# wa    12462
# wi    11166
# tn    10510
# co    10407
# il     9895
# nj     9338
# va     8754
# id     8249
# az     8228
# ia     8117
# ma     7992
# mn     7346
# ga     6294
# mt     6039
# ks     5946
# sc     5653
# ok     5610
# in     5502
# ct     5049
# al     4715
# md     4348
# ky     4060
# mo     3944
# nm     3861
# ak     3437
# ar     3260
# nv     3061
# nh     2944
# me     2761
# la     2760
# hi     2735
# dc     2663
# vt     2460
# ri     2281
# sd     1238
# ut     1126
# ne     1021
# wv     1003
# ms      974
# de      896
# wy      573
# nd      390
# Name: state, dtype: int64

# %% [markdown]
# the state data is very imbalance. the state like california has 45k+ records while state like north dakota and wyoming has less than 1k records.

# %%
# prompt: separate all the records that has word 'civic' in model column. keep in mind there is nan value in this column

df_civic = df[df['model'].str.contains('civic', case=False, na=False)]

# Display the first few rows of the filtered DataFrame
df_civic
# Out:
#         price    year manufacturer              model  condition    cylinders  \
# 74      26590  2020.0        honda  civic si coupe 2d       good          NaN
# 75      18590  2018.0        honda  civic lx sedan 4d       good          NaN
# 77      21590  2018.0        honda  civic ex sedan 4d       good          NaN
# 530      3500  1995.0        honda   civic del sol si       good  4 cylinders
# 589      3950  2003.0        honda           civic ex  excellent  4 cylinders
# ...       ...     ...          ...                ...        ...          ...
# 426428  18590  2016.0        honda  civic lx sedan 4d       good          NaN
# 426537  11280  2015.0        honda              civic       good          NaN
# 426737   2500  2005.0        honda              civic       good  4 cylinders
# 426848   4277  2005.0        honda              civic        NaN          NaN
# 426852   6977  2011.0        honda              civic        NaN          NaN
#
# ...

# %%
# prompt: Using dataframe df_civic: find the unique value in model columns and its frequency

print(df_civic['model'].value_counts())
# Out:
# civic                     2597
# civic lx                   477
# civic ex                   327
# civic si coupe 2d          182
# civic sedan                130
#                           ...
# civic sport hatch back       1
# civic sport sensing          1
# civic ex turbo               1
# civic cvcc                   1
# civic ex-l 1.8l              1
# Name: model, Length: 234, dtype: int64

# %% [markdown]
# from above code it is clear that we have maximum honda civic car named only with civic that is 2.5k+ while other models of civic are named very few times. So we will go with a general name that represent all sub-models of honda civic that is 'civic'.

# %%
# prompt: replace all the records that has word 'civic' with 'civic' in model column in df dataframe

df['model'] = df['model'].apply(lambda x: 'odyssey' if isinstance(x, str) and 'oddysey' in x else x)

# %%
df[df['model'].str.contains('crv', case=False, na=False)]
# Out:
#         price    year manufacturer            model  condition    cylinders  \
# 178     12950  2011.0        honda           crv ex  excellent  4 cylinders
# 487     11990  2011.0        honda         crv ex-l  excellent  4 cylinders
# 1167    12950  2011.0        honda           crv ex  excellent  4 cylinders
# 1613     3200  1997.0        honda       crv ex awd       good  4 cylinders
# 1834    27345  2019.0        honda  crv touring suv        NaN          NaN
# ...       ...     ...          ...              ...        ...          ...
# 423162   7990  2008.0        honda              crv  excellent  6 cylinders
# 423402  24995  2018.0        honda         crv ex-l  excellent  4 cylinders
# 423772   7995  2012.0        honda              crv        NaN          NaN
# 424761   7990  2008.0        honda              crv  excellent  6 cylinders
# 426019   6995  2007.0        honda       crv ex awd  excellent  4 cylinders
#
# ...

# %%
df['model'] = df['model'].apply(lambda x: 'crv' if isinstance(x, str) and 'cr v' in x else x)

# %%
# prompt: find all the unique value of model column given manufacturer column=honda and its frequency.

model_counts = df[df['manufacturer'] == 'honda']['model'].value_counts()

print("\nModel frequency:")
print(model_counts[0:15])
# Out:
# Model frequency:
# civic                       5371
# accord                      5047
# crv                         3040
# odyssey                     2099
# pilot                       1622
# fit                          806
# ridgeline                    532
# hrv                          245
# element                      207
# crosstour ex-l sport          82
# crosstour                     48
# insight                       36
# passport sport suv 4d         32
# insight touring sedan 4d      30
# passport                      30
# Name: model, dtype: int64

# %%
# prompt: find all the unique value of model column given manufacturer column=honda

honda_models = df[df['manufacturer'] == 'honda']['model'].unique()
print(honda_models)
# Out:
# ['odyssey' 'civic' nan 'crv' 'ridgeline' 'accord' 'pilot' 'element ex'
#  'crosstour ex-l' 'acty' 'cbr650' 'passport elite' 'crx' 'hrv' 'element'
#  'fit' 'crx si' 'element sc' 'passport sport suv 4d'
#  'insight touring sedan 4d' 'cr-z' 'clarity plug-in hybrid'
#  'element lx awd' 'passport' 'crosstour ex-l sport' 'beat' 'hr v'
#  'crosstour' 'insight' 's2000' 'oddessy exl' 'odessey ex-l'
#  'element ex awd' 'civi ex' 'insight ex' 'prelude si'
#  'passport ex-l sport' 'element ex 4wd at w/ front side airbags'
#  'passport elite awd' 'insight hybrid ex' 'insight hybrid'
#  'insight ex sedan 4d' 'oddessy' 'van' 'prelude' 'cr-z ex'
#  'cng ngv natural gas' 'g80 3.8' 'insight touring' 'crx dx' 'cr-z hybrid'
#  'insight lx' 's2000 convertible 6 speed' 'gl-1500-6' 'acty minitruck'
#  'charity plug-in touring' 'crosstour hatchback suv'
#  'element - all wheel drive' 'element awd' 'exspress 1981'
#  'passport touring sport' 'cr-z ex coupe 2d' 'passport elite sport'
# ...

# %%
# prompt: find all the unique value of model column given manufacturer column=honda and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

honda_models_with_counts = df[df['manufacturer'] == 'honda']['model'].value_counts()
models_to_drop = honda_models_with_counts[honda_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %%
# prompt: find all the unique value of model column given manufacturer column=honda

honda_models = df[df['manufacturer'] == 'honda']['model'].unique()
print(honda_models)
# Out:
# ['odyssey' 'civic' nan 'crv' 'accord' 'pilot']

# %% [markdown]
# for chevrolet

# %%
# prompt: find all the unique value of model column given manufacturer column=chevrolet from df fataframe

chevrolet_models_with_counts = df[df['manufacturer'] == 'chevrolet']['model'].value_counts()
print(chevrolet_models_with_counts)
# Out:
# silverado 1500                                       4546
# silverado                                            2778
# equinox                                              1769
# corvette                                             1607
# malibu                                               1577
#                                                      ...
# s10 extcab                                              1
# silverado 2500hd work truck crew cab long box 4wd       1
# silverado z71/ltz                                       1
# prizm base                                              1
# 1500 z71                                                1
# Name: model, Length: 2478, dtype: int64

# %%
df['model'] = df['model'].apply(lambda x: 'traverse' if isinstance(x, str) and 'traverse ' in x else x)

# %%
# prompt: find all the unique value of model column given manufacturer column=chevrolet and also print the frequency

chevrolet_models = df[df['manufacturer'] == 'chevrolet']['model'].unique()
chevrolet_models_with_counts = df[df['manufacturer'] == 'chevrolet']['model'].value_counts()
print("Unique models of Chevrolet and their frequency:")
for model, count in chevrolet_models_with_counts.items():
    print(f"\t- {model}: {count}")
# Out:
# Unique models of Chevrolet and their frequency:
# 	- silverado: 15585
# 	- corvette: 2866
# 	- equinox: 2858
# 	- cruze: 2599
# 	- tahoe: 2563
# 	- malibu: 2445
# 	- impala: 2409
# 	- camaro: 2378
# 	- colorado: 1889
# 	- suburban: 1536
# 	- traverse: 1341
# 	- trailblazer: 449
# 	- avalanche: 427
# 	- express cargo van: 297
# 	- sonic: 295
# 	- spark: 294
# 	- express: 273
# 	- cobalt: 268
# 	- trax: 238
# 	- trax lt sport utility: 214
# 	- hhr: 213
# 	- 2500: 184
# 	- c10: 180
# 	- express commercial cutaway: 176
# 	- blazer: 167
# 	- express 2500: 147
# 	- el camino: 133
# 	- volt: 128
# 	- sonic lt: 125
# 	- spark activ hatchback: 124
# 	- aveo: 121
# 	- express 3500: 121
# 	- hhr lt: 106
# 	- 3500: 106
# 	- monte carlo: 101
# 	- 1500: 99
# 	- trax lt: 96
# 	- cavalier: 92
# 	- express cargo: 91
# 	- express passenger: 89
# 	- trailblazer ls: 84
# 	- s10: 82
# 	- cc4500: 80
# 	- spark ev 2lt hatchback: 77
# 	- blazer 2lt sport: 73
# 	- s10 pickup: 72
# 	- nova: 68
# ...

# %%
# prompt: find all the unique value of model column given manufacturer column=chevrolet and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

chevrolet_models_with_counts = df[df['manufacturer'] == 'chevrolet']['model'].value_counts()
models_to_drop = chevrolet_models_with_counts[chevrolet_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# for gmc

# %%
#find all the unique value of model column given manufacturer column=gmc from df fataframe

gmc_models_with_counts = df[df['manufacturer'] == 'gmc']['model'].value_counts()
print(gmc_models_with_counts)
# Out:
# sierra                    6325
# yukon                     2312
# acadia                    1615
# terrain                   1149
# canyon                     447
#                           ...
# c7h top kick                 1
# w3500                        1
# sprint                       1
# c-5500 38 foot utility       1
# sevana (custom)              1
# Name: model, Length: 291, dtype: int64

# %%
df['model'] = df['model'].apply(lambda x: 'acadia' if isinstance(x, str) and 'arcadia' in x else x)

# %%
# find all the unique value of model column given manufacturer column=gmc and also print the frequency

gmc_models = df[df['manufacturer'] == 'gmc']['model'].unique()
gmc_models_with_counts = df[df['manufacturer'] == 'gmc']['model'].value_counts()
print("Unique models of gmc and their frequency:")
for model, count in gmc_models_with_counts.items():
    print(f"\t- {model}: {count}")
# Out:
# Unique models of gmc and their frequency:
# 	- sierra: 6325
# 	- yukon: 2312
# 	- acadia: 1615
# 	- terrain: 1149
# 	- canyon: 447
# 	- savana: 423
# 	- sonoma: 62
# 	- suburban: 55
# 	- tc5500: 29
# 	- envoy xl: 29
# 	- jimmy: 25
# 	- envoy denali: 22
# 	- safari: 20
# 	- envoy sle: 20
# 	- sonoma sls: 20
# 	- envoy slt: 19
# 	- denali: 17
# 	- envoy slt 4x4: 13
# 	- 1500 sierra: 11
# 	- starcraft: 10
# 	- c5500 24 foot flatbed 8.1l gas: 10
# 	- vandura 3500: 9
# 	- c8500 tandem dump truck: 9
# 	- c5500 topkick: 9
# 	- 2wd: 8
# 	- c7500 dump truck: 8
# 	- vandura 2500: 8
# 	- envoy 4x4: 7
# 	- envoy xuv: 7
# 	- caballero: 6
# 	- brigadier: 6
# 	- envoy 4x4 xuv 5.3l v8 slt loaded low miles one owner: 6
# 	- top kick: 6
# 	- sonoma sl: 6
# 	- envoy sle 4wd: 6
# 	- jimmy sle: 6
# 	- jimmy slt: 5
# 	- safari passenger: 5
# 	- c5500 bucket truck: 5
# 	- denali 2500hd diesel sierra: 5
# 	- savanna: 4
# 	- vandura: 4
# 	- jimmy 4x4: 4
# 	- kodiak 5500: 4
# 	- envoy new sticker: 4
# ...

# %%
# find all the unique value of model column given manufacturer column=gmc and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

gmc_models_with_counts = df[df['manufacturer'] == 'gmc']['model'].value_counts()
models_to_drop = gmc_models_with_counts[gmc_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# jeep

# %%
#find all the unique value of model column given manufacturer column=jeep from df dataframe

jeep_models_with_counts = df[df['manufacturer'] == 'jeep']['model'].value_counts()
print(jeep_models_with_counts)
# Out:
# wrangler                7509
# cherokee                5135
# liberty                 1087
# patriot                  611
# compass                  562
#                         ...
# compass 4x4 latitude       1
# m52                        1
# kaiser                     1
# compass trailblazer        1
# gand wagoneer              1
# Name: model, Length: 284, dtype: int64

# %%
df['model'] = df['model'].apply(lambda x: 'cherokee' if isinstance(x, str) and 'grand cherokee' in x else x)

# %%
# find all the unique value of model column given manufacturer column=jeep and also print the frequency

jeep_models = df[df['manufacturer'] == 'jeep']['model'].unique()
jeep_models_with_counts = df[df['manufacturer'] == 'jeep']['model'].value_counts()
print("Unique models of jeep and their frequency:")
for model, count in jeep_models_with_counts.items():
    print(f"\t- {model}: {count}")
# Out:
# Unique models of jeep and their frequency:
# 	- wrangler: 7509
# 	- cherokee: 5135
# 	- liberty: 1087

# %%
# find all the unique value of model column given manufacturer column=jeep and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

jeep_models_with_counts = df[df['manufacturer'] == 'jeep']['model'].value_counts()
models_to_drop = jeep_models_with_counts[jeep_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# for dodge

# %%
#find all the unique value of model column given manufacturer column=dodge from df dataframe

dodge_models_with_counts = df[df['manufacturer'] == 'dodge']['model'].value_counts()
print(dodge_models_with_counts)
# Out:
# caravan                2562
# charger                2249
# challenger             1945
# durango                1208
# journey                1174
#                        ...
# brothers                  1
# d 150                     1
# sprinter wheelchair       1
# truck d100                1
# avenger, se               1
# Name: model, Length: 341, dtype: int64

# %%
df['model'] = df['model'].apply(lambda x: 'journey' if isinstance(x, str) and 'journey ' in x else x)

# %%
# find all the unique value of model column given manufacturer column=dodge and also print the frequency

dodge_models = df[df['manufacturer'] == 'dodge']['model'].unique()
dodge_models_with_counts = df[df['manufacturer'] == 'dodge']['model'].value_counts()
print("Unique models of dodge and their frequency:")
for model, count in dodge_models_with_counts.items():
    print(f"\t- {model}: {count}")
# Out:
# Unique models of dodge and their frequency:
# 	- caravan: 2562
# 	- charger: 2249
# 	- challenger: 1945
# 	- durango: 1205
# 	- journey: 1174
# 	- dakota: 574
# 	- dart: 351
# 	- avenger: 313
# 	- caliber: 150
# 	- nitro: 126
# 	- dart sxt: 102
# 	- neon: 66
# 	- caliber sxt: 53
# 	- avenger se: 53
# 	- stratus: 50
# 	- avenger sxt: 47
# 	- avenger r/t: 30
# 	- nitro slt: 26
# 	- dart se: 25
# 	- magnum: 25
# 	- dart limited: 25
# 	- dart se sedan 4d: 23
# 	- sprinter 2500: 20
# 	- magnum sxt: 20
# 	- dart gt: 19
# 	- nitro sxt: 17
# 	- coronet: 17
# 	- d100: 16
# 	- neon sxt: 15
# 	- dart rallye: 14
# 	- ramcharger: 13
# 	- caliber r/t: 13
# 	- sprinter 3500: 12
# 	- intrepid: 11
# 	- power wagon: 11
# 	- dart aero: 11
# 	- coronet 440: 10
# 	- dart swinger: 10
# 	- stealth: 10
# 	- dart sxt sedan 4d: 10
# 	- stratus sxt: 9
# 	- sprinter: 9
# 	- d250: 9
# 	- dart limited/gt: 9
# 	- dart aero sedan 4d: 9
# 	- magnum r/t: 8
# 	- nitro se: 8
# 	- nitro r/t: 8
# 	- dart sxt sedan: 7
# ...

# %%
# find all the unique value of model column given manufacturer column=dodge and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

dodge_models_with_counts = df[df['manufacturer'] == 'dodge']['model'].value_counts()
models_to_drop = dodge_models_with_counts[dodge_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# for mercedes-benz

# %%
# prompt: count the total records where manufacturer = mercedes-benz

mercedes_count = df[df['manufacturer'] == 'mercedes-benz'].shape[0]
print(f"Total Mercedes-Benz cars: {mercedes_count}")
# Out:
# Total Mercedes-Benz cars: 10266

# %%
#find all the unique value of model column given manufacturer column='mercedes-benz' from df dataframe

mercedes_models_with_counts = df[df['manufacturer'] == 'mercedes-benz']['model'].value_counts()
print(mercedes_models_with_counts)
# Out:
# c-class               2421
# benz                  2168
# g-class               1774
# e-class               1406
# s-class               1161
#                       ...
# 560sec                   1
# bennz 420sel             1
# 420 sel                  1
# amg g 63                 1
# porsche. bmw. ect.       1
# Name: model, Length: 141, dtype: int64

# %%
import re

regex_list = [r"e[a-z]{0,3}[0-9]{0,3}", r"c[a-z]{0,3}[0-9]{0,3}", r"s[a-z]{0,3}[0-9]{0,3}", r"m[a-z]{0,3}[0-9]{0,3}", r"g[a-z]{0,3}[0-9]{0,3}"]
regex_class = ["e-class","c-class","s-class","m-class", "g-class"]

for i in range(5):
    # Check if manufacturer is 'Hyundai' before applying the transformation
    df.loc[df['manufacturer'] == 'mercedes-benz', 'model'] = df.loc[df['manufacturer'] == 'mercedes-benz', 'model'].apply(lambda x: regex_class[i] if isinstance(x, str) and re.match(regex_list[i],x) else x)

# %%
df.loc[df['manufacturer'] == 'mercedes-benz', 'model'] = df.loc[df['manufacturer'] == 'mercedes-benz', 'model'].apply(lambda x: 'benz' if isinstance(x, str) and 'benz ' in x else x)

# %%
# find all the unique value of model column given manufacturer column=mercedes-benz and also print the frequency

mercedes_models = df[df['manufacturer'] == 'mercedes-benz']['model'].unique()
mercedes_models_with_counts = df[df['manufacturer'] == 'mercedes-benz']['model'].value_counts()
print("Unique models of dodge and their frequency:")
for model, count in mercedes_models_with_counts.items():
    print(f"\t- {model}: {count}")
# Out:
# Unique models of dodge and their frequency:
# 	- c-class: 2421
# 	- benz: 2168
# 	- g-class: 1774
# 	- e-class: 1406
# 	- s-class: 1161
# 	- m-class: 823
# 	- b-class: 29
# 	- a-class a 220: 25
# 	- 500-class: 24
# 	- b-class electric: 19
# 	- b-class b 250e: 14
# 	- r-class: 14
# 	- 380sl: 13
# 	- 300d: 13
# 	- amg gt: 12
# 	- 240d: 10
# 	- r350: 9
# 	- 450sl: 9
# 	- 500sl: 7
# 	- 560 sl: 7
# 	- 450 sl: 6
# 	- 560-class: 6
# 	- r-class r 350: 5
# 	- 560sl: 5
# 	- r320 cdi: 4
# 	- 250 s: 4
# 	- a-class: 4
# 	- amg c 43: 4
# 	- 300cd: 4
# 	- awd *gl 450 4matic 4dr*suv*clean*carfax *3row seat nav: 4
# 	- 380 sl: 3
# 	- 300se: 3
# 	- 40k mile $362.47, $2000 down, only 40k miles $362.47,luxury low miles $2000 down, only 40k miles: 3
# 	- 300: 3
# 	- 350sl: 3
# 	- 450slc: 3
# 	- 300-class: 3
# 	- 230ge: 2
# 	- ben: 2
# 	- 560: 2
# 	- 300 cd: 2
# 	- r350 4matic: 2
# 	- 560 sel: 2
# 	- bens s550: 2
# 	- 450-class: 2
# 	- benz-e500 5.0l v8: 2
# 	- 300 e: 2
# 	- amg gle 43: 2
# 	- 300sd: 2
# ...

# %%
# find all the unique value of model column given manufacturer column=mercedes and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

mercedes_models_with_counts = df[df['manufacturer'] == 'mercedes-benz']['model'].value_counts()
models_to_drop = mercedes_models_with_counts[mercedes_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# for cadillac

# %%
#find all the unique value of model column given manufacturer column='cadillac' from df dataframe

cadillac_models_with_counts = df[df['manufacturer'] == 'cadillac']['model'].value_counts()
print(cadillac_models_with_counts)
# Out:
# xts                      1262
# escalade                  706
# ats                       569
# cts                       567
# dts                       553
#                          ...
# stx4 all wheel drive.       1
# cts-4                       1
# escalade esv 4x4            1
# cts sedan sdn 2.0l          1
# srx4 premium                1
# Name: model, Length: 286, dtype: int64

# %%
import re

reg_list=[r"xt*", r"at*",r"dt*", r"ct*", r"sr*"]
reg_class = ["xts","ats","dts", "cts","srx"]

for i in range(5):
  df.loc[df['manufacturer'] == 'cadillac', 'model'] = df.loc[df['manufacturer'] == 'cadillac', 'model'].apply(lambda x: reg_class[i] if isinstance(x, str) and re.match(reg_list[i], x) else x)

# %%
df.loc[df['manufacturer'] == 'cadillac', 'model'] = df.loc[df['manufacturer'] == 'cadillac', 'model'].apply(lambda x: 'escalade' if isinstance(x, str) and 'escalade ' in x else x)

# %%
# find all the unique value of model column given manufacturer column=cadillac and also print the frequency

cadillac_models = df[df['manufacturer'] == 'cadillac']['model'].unique()
cadillac_models_with_counts = df[df['manufacturer'] == 'cadillac']['model'].value_counts()
print("Unique models of cadillac and their frequency:")
for model, count in cadillac_models_with_counts.items():
    print(f"\t- {model}: {count}")
# Out:
# Unique models of cadillac and their frequency:
# 	- cts: 1631
# 	- escalade: 1303
# 	- xts: 1262
# 	- ats: 569
# 	- dts: 553
# 	- srx: 489
# 	- eldorado: 80
# 	- fleetwood: 21
# 	- fleetwood brougham: 20
# 	- eldorado biarritz: 12
# 	- eldorado esc: 10
# 	- brougham: 10
# 	- limousine: 8
# 	- eldorado convertible: 6
# 	- eldorado etc: 5
# 	- hearse: 5
# 	- elr coupe 2d: 5
# 	- lasalle: 4
# 	- ext: 3
# 	- professional: 2
# 	- el dorado: 2
# 	- fleetwood 60: 2
# 	- fleetwood limo: 2
# 	- touring car: 1
# 	- braughm: 1
# 	- lemousine: 1
# 	- eldorado￼: 1
# 	- eldorado touring coupe: 1
# 	- fleetwood limousine: 1
# 	- el dorado biarritz: 1
# 	- 62 series: 1
# 	- vma: 1
# 	- esclade ext: 1
# 	- eldorad: 1
# 	- escalate: 1
# 	- northstar sls: 1
# 	- v-series: 1
# 	- fleetwood sixty special: 1
# 	- rxs: 1
# 	- elderado: 1
# 	- eagle hearse: 1
# 	- limo: 1
# 	- elr: 1
# 	- luxury: 1
# 	- fleetwood seventy-five: 1
# 	- premium luxury xts: 1
# 	- eldorodo: 1
# 	- eldorado coupe: 1

# %%
# find all the unique value of model column given manufacturer column=cadillac and its frequency. for all the items with frequency less than 500. drop the record from 'df' dataframe

cadillac_models_with_counts = df[df['manufacturer'] == 'cadillac']['model'].value_counts()
models_to_drop = cadillac_models_with_counts[cadillac_models_with_counts < 500].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# volkswagen

# %%
#find all the unique value of model column given manufacturer column='volkswagen' from df dataframe

volkswagen_models_with_counts = df[df['manufacturer'] == 'volkswagen']['model'].value_counts()
print(volkswagen_models_with_counts)
# Out:
# jetta                   1254
# passat                   710
# tiguan                   500
# beetle                   401
# beetle 1.8t fleet        199
#                         ...
# superbettle                1
# jetta 1.8t sel sedan       1
# cc sportsedan 6a w         1
# cc vr6                     1
# jetta 1.4 t r-line         1
# Name: model, Length: 675, dtype: int64

# %%
df.loc[df['manufacturer'] == 'volkswagen', 'model'] = df.loc[df['manufacturer'] == 'volkswagen', 'model'].apply(lambda x: 'beetle' if isinstance(x, str) and 'new beetle' in x else x)

# %%
# find all the unique value of model column given manufacturer column=volkswagen and also print the frequency

volkswagen_models = df[df['manufacturer'] == 'volkswagen']['model'].unique()
volkswagen_models_with_counts = df[df['manufacturer'] == 'volkswagen']['model'].value_counts()
print("Unique models of dodge and their frequency:")
for model, count in volkswagen_models_with_counts.items():
    print(f"\t- {model}: {count}")
# Out:
# Unique models of dodge and their frequency:
# 	- jetta: 2553
# 	- golf: 1235
# 	- beetle: 1056
# 	- passat: 1052
# 	- tiguan: 805
# 	- atlas: 394
# 	- gti: 306
# 	- touareg tdi sport suv: 120
# 	- eos komfort: 104
# 	- touareg: 91
# 	- rabbit: 90
# 	- eos sport convertible: 88
# 	- cc sport: 51
# 	- routan: 45
# 	- eos: 37
# 	- vanagon: 36
# 	- bug: 29
# 	- routan se: 21
# 	- karmann ghia: 20
# 	- vanagon westfalia: 19
# 	- e-golf: 18
# 	- eurovan camper: 17
# 	- eurovan: 17
# 	- thing: 12
# 	- arteon sel r-line: 11
# 	- r32: 10
# 	- routan sel: 10
# 	- cc 3.6 vr6 4motion: 9
# 	- westfalia: 8
# 	- touareg tdi: 8
# 	- eurovan weekender: 8
# 	- cabrio convertible: 8
# 	- cc 2.0t r-line sedan: 8
# 	- eurovan gls: 8
# 	- cabrio: 7
# 	- eurovan campmobile: 7
# 	- eos 2.0t: 6
# 	- cc r-line: 6
# 	- gli: 6
# 	- routan smini van: 6
# 	- cabriolet: 6
# 	- eurovan mv: 5
# 	- rabbit pickup: 5
# 	- vanagon l bus: 5
# 	- arteon: 5
# 	- touareg awd: 5
# 	- cc 2.0t sport sedan: 5
# ...

# %%
# find all the unique value of model column given manufacturer column=volkswagen and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

volkswagen_models_with_counts = df[df['manufacturer'] == 'volkswagen']['model'].value_counts()
models_to_drop = volkswagen_models_with_counts[volkswagen_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# for subaru

# %%
#find all the unique value of model column given manufacturer column='subaru' from df dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print(subaru_models_with_counts)
# Out:
# outback                      1449
# forester                     1257
# impreza                       919
# legacy                        626
# wrx                           352
#                              ...
# outback premium 2.5i            1
# xv crosstrek 2.0 limited        1
# wrx sti limited awd             1
# crosstrek 2.0 limited awd       1
# impreza 2.0i sport ltd          1
# Name: model, Length: 581, dtype: int64

# %%
#changing the cars' submodels into a general model.
df.loc[df['manufacturer'] == 'subaru', 'model'] = df.loc[df['manufacturer'] == 'subaru', 'model'].apply(lambda x: 'crosstrek' if isinstance(x, str) and 'xv crosstrek' in x else x)

# %%
# find all the unique value of model column given manufacturer column=volkswagen and also print the frequency

subaru_models = df[df['manufacturer'] == 'subaru']['model'].unique()
subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print("Unique models of subaru and their frequency:")
for model, count in subaru_models_with_counts.items():
    print(f"\t- {model}: {count}")
# Out:
# Unique models of subaru and their frequency:
# 	- outback: 2236
# 	- forester: 1986
# 	- impreza: 1719
# 	- legacy: 1116
# 	- wrx: 755
# 	- crosstrek: 743
# 	- brz limited coupe 2d: 83
# 	- tribeca: 37
# 	- ascent: 33
# 	- brz: 32
# 	- b9 tribeca: 19
# 	- tribeca limited: 19
# 	- baja sport arizona rust free* all service records since new*new timing belt*new brakes&rotors*new tune up*new tires*new struts*smoke free*zero oil leaks*rare find: 17
# 	- brz limited: 13
# 	- brz premium coupe 2d: 9
# 	- tribeca 3.6r limited: 9
# 	- baja sport: 8
# 	- ascent premium sport: 7
# 	- forrester: 5
# 	- tribeca b9: 5
# 	- baja turbo: 4
# 	- sti: 4
# 	- b9 tribeca 5-pass ltd: 3
# 	- ascent limited awd: 3
# 	- svx: 3
# 	- tribeca ltd awd: 3
# 	- ascent limited: 3
# 	- putback: 2
# 	- forster: 2
# 	- ascent premium: 2
# 	- imprza limited wagon: 2
# 	- justy: 2
# 	- inpreza limited awd: 2
# 	- brat: 2
# 	- tribeca awd: 2
# 	- impeza: 2
# 	- b9 tribeca limited: 2
# 	- brat gl: 1
# ...

# %%
# find all the unique value of model column given manufacturer column=subaru and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
models_to_drop = subaru_models_with_counts[subaru_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# for Hyundai

# %%
#find all the unique value of model column given manufacturer column='hyundai' from df dataframe

hyundai_models_with_counts = df[df['manufacturer'] == 'hyundai']['model'].value_counts()
print(hyundai_models_with_counts)
# Out:
# sonata                                   1480
# elantra                                  1329
# tucson                                    487
# accent                                    378
# veloster                                  323
#                                          ...
# sonata sport sedan                          1
# tucson night fwd                            1
# santa fe sport 2.4l auto                    1
# kona sel 2.0l auto w/contrasting roof       1
# tucson, gls                                 1
# Name: model, Length: 453, dtype: int64

# %%
#changing the cars' submodels into a general model.
df.loc[df['manufacturer'] == 'hyundai', 'model'] = df.loc[df['manufacturer'] == 'hyundai', 'model'].apply(lambda x: 'genesis' if isinstance(x, str) and 'genesis ' in x else x)

# %%
# find all the unique value of model column given manufacturer column=hyundai and also print the frequency

hyundai_models = df[df['manufacturer'] == 'hyundai']['model'].unique()
hyundai_models_with_counts = df[df['manufacturer'] == 'hyundai']['model'].value_counts()
print("Unique models of hyundai and their frequency:")
for model, count in hyundai_models_with_counts.items():
    print(f"\t- {model}: {count}")
# Out:
# Unique models of hyundai and their frequency:
# 	- sonata: 2759
# 	- elantra: 2037
# 	- santa fe: 723
# 	- tucson: 723
# 	- accent: 628
# 	- genesis: 526
# 	- veloster: 498
# 	- kona: 98
# 	- veracruz: 43
# 	- azera: 39
# 	- ioniq plug-in hybrid: 38
# 	- equus: 30
# 	- equus signature sedan 4d: 27
# 	- entourage: 25
# 	- azera limited: 20
# 	- tiburon gt: 18
# 	- azera sedan 4d: 15
# 	- ioniq hybrid sel: 15
# 	- tiburon: 15
# 	- veracruz limited: 13
# 	- ioniq hybrid: 12
# 	- equus signature: 11
# 	- palisade sel sport: 11
# 	- kona se: 11
# 	- venue sel sport utility: 11
# 	- kona electric ultimate: 9
# 	- ioniq electric: 8
# 	- palisade se sport: 8
# 	- sante fe: 7
# 	- tuscon: 7
# 	- ioniq: 7
# 	- xg350: 7
# 	- kona ultimate sport: 6
# 	- tiburon gt v6: 6
# 	- ioniq hybrid limited: 6
# 	- entourage limited: 5
# 	- entourage gls: 5
# 	- ioniq electric limited: 5
# 	- equus ultimate: 4
# 	- palisade: 4
# 	- palisade limited sport: 4
# 	- kona sel: 4
# 	- venue: 4
# ...

# %%
# find all the unique value of model column given manufacturer column=hyundai and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

hyundai_models_with_counts = df[df['manufacturer'] == 'hyundai']['model'].value_counts()
models_to_drop = hyundai_models_with_counts[hyundai_models_with_counts < 500].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# for ram

# %%
#find all the unique value of model column given manufacturer column='ram' from df dataframe

ram_models_with_counts = df[df['manufacturer'] == 'ram']['model'].value_counts()
print(ram_models_with_counts)
# Out:
# 1500 crew cab big horn          635
# 1500 classic regular cab        383
# 1500 quad cab harvest pickup    174
# 1500 slt                        133
# 1500 laramie                    126
#                                ...
# 4x4 crew                          1
# 3500 4x4 tradesman                1
# laramie 3500                      1
# 1500 sprt                         1
# 1500 longhorn 4x4                 1
# Name: model, Length: 892, dtype: int64

# %%
#changing the cars' submodels into a general model.
df.loc[df['manufacturer'] == 'ram', 'model'] = df.loc[df['manufacturer'] == 'ram', 'model'].apply(lambda x: 'deisel' if isinstance(x, str) and 'deisel ' in x else x)

# %%
# find all the unique value of model column given manufacturer column=volkswagen and also print the frequency

ram_models = df[df['manufacturer'] == 'ram']['model'].unique()
ram_models_with_counts = df[df['manufacturer'] == 'ram']['model'].value_counts()
print("Unique models of ram and their frequency:")
for model, count in ram_models_with_counts.items():
    print(f"\t- {model}: {count}")
# Out:
# Unique models of ram and their frequency:
# 	- 1500 model: 4278
# 	- 2500 model: 1364
# 	- 3500 model: 730
# 	- promaster: 281
# 	- deisel: 140
# 	- chassis cab: 23
# 	- c/v: 19
# 	- 5500 tradesman: 16
# 	- slt: 11
# 	- chassis 3500: 11
# 	- rebel: 8
# 	- cummins 2500: 7
# 	- cv: 5
# 	- charger: 5
# 	- van 1500: 5
# 	- 50: 5
# 	- c/v tradesman: 5
# 	- c/v cargo van: 5
# 	- slt crew cab: 4
# 	- quad cab laramie: 4
# 	- van 2500: 4
# 	- 4500hd: 3
# 	- 5500 chassis cab: 3
# 	- 3500hd 4x4 crew-cab utility truck: 3
# 	- silverado: 3
# 	- trx: 3
# 	- cargo van tradesman: 3
# 	- van 3500: 3
# 	- 5500 crew cab 4x4 flat bed drw: 3
# 	- limited night edition: 2
# 	- hd megacab 4x4: 2
# 	- van b2500: 2
# 	- big horn: 2
# 	- quad cab big horn 4wd: 2
# 	- cummin 2500: 2
# 	- quad cab slt 4wd: 2
# 	- quad cab sport 4wd: 2
# 	- b350: 2
# 	- 4500 wrecker: 2
# 	- 150: 2
# 	- laramie crew cab 4x4: 2
# 	- 5500 chassis cab tradesman: 2
# 	- cummin 3500: 2
# 	- ext cab slt 4x4: 2
# 	- srt10: 2
# ...

# %%
# find all the unique value of model column given manufacturer column=ram and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

ram_models_with_counts = df[df['manufacturer'] == 'ram']['model'].value_counts()
models_to_drop = ram_models_with_counts[ram_models_with_counts < 500].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# for lexus

# %%
df = pd.read_csv('/content/cars3.csv')

# %%
#find all the unique value of model column given manufacturer column='lexus' from df dataframe

lexus_models_with_counts = df[df['manufacturer'] == 'lexus']['model'].value_counts()
print(lexus_models_with_counts)
# Out:
# rx 350                     511
# es 350                     422
# ls 460 sedan 4d            335
# nx 300 sport utility 4d    222
# gs 350 sedan 4d            221
#                           ...
# es 250                       1
# ls-460                       1
# rx-350                       1
# es 350 ultra luxury          1
# lx 470 4dr suv               1
# Name: model, Length: 444, dtype: int64

# %%
#changing the cars' submodels into a general model.

df.loc[df['manufacturer'] == 'lexus', 'model'] = df.loc[df['manufacturer'] == 'lexus', 'model'].apply(lambda x: 'nx series' if isinstance(x, str) and 'nx' in x else x)

# %%
# find all the unique value of model column given manufacturer column=volkswagen and also print the frequency

lexus_models = df[df['manufacturer'] == 'lexus']['model'].unique()
lexus_models_with_counts = df[df['manufacturer'] == 'lexus']['model'].value_counts()
print("Unique models of lexus and their frequency:")
for model, count in lexus_models_with_counts.items():
    print(f"\t- {model}: {count}")
# Out:
# Unique models of lexus and their frequency:
# 	- rx series: 1800
# 	- es series: 1334
# 	- gx series: 1120
# 	- is series: 1084
# 	- ls series: 962
# 	- nx series: 651
# 	- ct 200h hatchback 4d: 93
# 	- rc 350: 83
# 	- ct: 46
# 	- ux 250h sport utility 4d: 45
# 	- ct 200h: 44
# 	- rc: 38
# 	- sc 430: 33
# 	- sc: 24
# 	- rc 350 coupe 2d: 22
# 	- sc 430 convertible: 22
# 	- hs: 17
# 	- sc430 convertible: 16
# 	- ct200h: 16
# 	- ct 200h premium hatchback: 15
# 	- dealer* luxury pkg* rear dvd* preffered pkg*mark levinson*2-keys*like new: 14
# 	- hs 250h: 14
# 	- sc430: 13
# 	- sc300: 11
# 	- ux 250h f sport suv 4d: 11
# 	- sc400: 11
# 	- ux 200 f sport suv 4d: 10
# 	- ct 200h hybrid: 10
# 	- rc 200t: 8
# 	- rc 300: 8
# 	- lc 500: 7
# 	- ux: 7
# 	- rc 350 f sport: 6
# 	- hs 250 premium: 6
# 	- sc 400: 6
# 	- rc f: 5
# 	- ct 200h premium: 5
# 	- rc 200t coupe 2d: 4
# 	- ct200h f sport: 4
# 	- rc-f: 4
# 	- rc 500: 4
# 	- ux 200 sport utility 4d: 3
# 	- hs 250h premium: 3
# ...

# %%
# find all the unique value of model column given manufacturer column=lexus and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

lexus_models_with_counts = df[df['manufacturer'] == 'lexus']['model'].value_counts()
models_to_drop = lexus_models_with_counts[lexus_models_with_counts < 900].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# for kia

# %%
#find all the unique value of model column given manufacturer column='kia' from df dataframe

kia_models_with_counts = df[df['manufacturer'] == 'kia']['model'].value_counts()
print(kia_models_with_counts)
# Out:
# soul                                     1795
# optima                                   1361
# forte                                    1050
# sportage                                  673
# rio                                       342
#                                          ...
# sorento lx 4d sport utility automatic       1
# niro ex 4d sport utility automatic          1
# stinger gt awd                              1
# sorento 4wd                                 1
# optima, ex                                  1
# Name: model, Length: 187, dtype: int64

# %%
#changing the cars' submodels into a general model
df.loc[df['manufacturer'] == 'kia', 'model'] = df.loc[df['manufacturer'] == 'kia', 'model'].apply(lambda x: 'rio' if isinstance(x, str) and 'rio ' in x else x)

# %%
# find all the unique value of model column given manufacturer column=kia and also print the frequency

kia_models = df[df['manufacturer'] == 'kia']['model'].unique()
kia_models_with_counts = df[df['manufacturer'] == 'kia']['model'].value_counts()
print("Unique models of kia and their frequency:")
for model, count in kia_models_with_counts.items():
    print(f"\t- {model}: {count}")
# Out:
# Unique models of kia and their frequency:
# 	- soul: 1795
# 	- optima: 1361
# 	- forte: 1050
# 	- sportage: 673
# 	- rio: 342
# 	- sedona: 177
# 	- sorento lx: 128
# 	- sorento lx sport utility 4d: 79
# 	- niro lx wagon 4d: 70
# 	- sedona lx: 61
# 	- k900 luxury sedan 4d: 44
# 	- amanti: 43
# 	- sorento ex: 42
# 	- k900 premium sedan 4d: 38
# 	- cadenza: 37
# 	- niro: 34
# 	- rondo: 32
# 	- sedona ex: 29
# 	- telluride lx sport utility: 27
# 	- niro s touring wagon 4d: 25
# 	- sorento ex sport utility 4d: 25
# 	- stinger: 25
# 	- telluride: 23
# 	- sorento sx: 22
# 	- spectra ex: 20
# 	- rondo lx: 17
# 	- forte5 lx hatchback 4d: 17
# 	- sorento sx sport utility 4d: 16
# 	- borrego: 16
# 	- forte5 ex hatchback 4d: 16
# 	- stinger gt sedan 4d: 15
# 	- sedona sx minivan 4d: 15
# 	- niro ev ex wagon 4d: 15
# 	- cadenza premium sedan 4d: 13
# 	- stinger gt-line sedan 4d: 12
# 	- rio5: 11
# 	- sorento lx awd: 11
# 	- sorento lx w/ 3rd row seating: 10
# 	- stinger premium: 10
# ...

# %%
# find all the unique value of model column given manufacturer column=kia and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

kia_models_with_counts = df[df['manufacturer'] == 'kia']['model'].value_counts()
models_to_drop = kia_models_with_counts[kia_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# for audi

# %%
#find all the unique value of model column given manufacturer column='audi' from df dataframe
audi_models_with_counts = df[df['manufacturer'] == 'audi']['model'].value_counts()
print(audi_models_with_counts)
# Out:
# a4                            646
# q5                            424
# a6                            280
# q7                            271
# a6 2.0t premium plus sedan    186
#                              ...
# a5 2.0 tfsi premium plus s      1
# a3 s line                       1
# all road 2.7t                   1
# a3 3.2 quattro sline            1
# a4 allroad quattro              1
# Name: model, Length: 611, dtype: int64

# %%
#changing the cars' submodels into a general model.
df.loc[df['manufacturer'] == 'audi', 'model'] = df.loc[df['manufacturer'] == 'audi', 'model'].apply(lambda x: 'q7' if isinstance(x, str) and 'q7:' in x else x)

# %%
# find all the unique value of model column given manufacturer column=audi and also print the frequency

audi_models = df[df['manufacturer'] == 'audi']['model'].unique()
audi_models_with_counts = df[df['manufacturer'] == 'audi']['model'].value_counts()
print("Unique models of audi and their frequency:")
for model, count in audi_models_with_counts.items():
    print(f"\t- {model}: {count}")
# Out:
# Unique models of audi and their frequency:
# 	- a4: 1428
# 	- q5: 1079
# 	- a6: 1034
# 	- q7: 493
# 	- a3: 158
# 	- q8 premium sport utility 4d: 153
# 	- s5 premium plus sedan 4d: 150
# 	- a5: 138
# 	- a7: 130
# 	- s5 premium plus coupe 2d: 127
# 	- q3: 108
# 	- s5 prestige coupe 2d: 89
# 	- s5: 89
# 	- tt: 83
# 	- s4: 77
# 	- a8: 66
# 	- s5 premium plus convertible: 55
# 	- sq5: 49
# 	- allroad premium plus wagon: 49
# 	- s5 prestige sedan 4d: 40
# 	- a3 premium sedan 4d: 39
# 	- a5 premium plus coupe 2d: 38
# 	- a5 premium coupe 2d: 38
# 	- s4 premium plus sedan 4d: 37
# 	- a3 e-tron: 37
# 	- allroad: 37
# 	- tt roadster: 35
# 	- a3 premium plus sedan 4d: 34
# 	- a5 premium plus sedan 4d: 32
# 	- s5 prestige convertible 2d: 30
# 	- a3 sportback e-tron premium: 30
# 	- s6: 29
# 	- s4 prestige sedan 4d: 27
# 	- s4 quattro: 26
# 	- a7 3.0t prestige quattro: 25
# 	- s6 prestige quattro awd: 23
# 	- s7 prestige sedan 4d: 23
# 	- s3 premium plus sedan 4d: 23
# 	- s7 sedan 4d: 22
# ...

# %%
# find all the unique value of model column given manufacturer column=volkswagen and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

audi_models_with_counts = df[df['manufacturer'] == 'audi']['model'].value_counts()
models_to_drop = audi_models_with_counts[audi_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# for acura

# %%
#find all the unique value of model column given manufacturer column='acura' from df dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'acura']['model'].value_counts()
print(subaru_models_with_counts)
# Out:
# mdx                                    719
# tl                                     470
# mdx sh-awd sport utility               464
# mdx sh-awd w/technology                259
# rdx                                    259
#                                       ...
# mdx sh-awd w/power tailgate w/sport      1
# integra se                               1
# legend l                                 1
# rdx base 4dr suv                         1
# rdxnsh/awd                               1
# Name: model, Length: 298, dtype: int64

# %%
#changing the cars' submodels into a general model.
df.loc[df['manufacturer'] == 'acura', 'model'] = df.loc[df['manufacturer'] == 'acura', 'model'].apply(lambda x: 'ilx' if isinstance(x, str) and 'ilx ' in x else x)

# %%
# find all the unique value of model column given manufacturer column=acura and also print the frequency

acura_models = df[df['manufacturer'] == 'acura']['model'].unique()
acura_models_with_counts = df[df['manufacturer'] == 'acura']['model'].value_counts()
print("Unique models of acura and their frequency:")
for model, count in acura_models_with_counts.items():
    print(f"\t- {model}: {count}")
# Out:
# Unique models of acura and their frequency:
# 	- mdx: 2111
# 	- tl: 1656
# 	- rdx: 1066
# 	- ilx: 530
# 	- rl: 66
# 	- rsx: 42
# 	- rlx sedan 4d: 18
# 	- rlx: 17
# 	- rlx sport hybrid sh-awd: 15
# 	- 3.2 tl: 15
# 	- cl: 11
# 	- integra: 11
# 	- rl sh-awd w/tech: 11
# 	- nsx: 10
# 	- integra ls: 7
# 	- 3.2tl: 6
# 	- rl sh-awd: 6
# 	- cl type s: 6
# 	- 3.2 cl type s: 5
# 	- 3.0cl: 3
# 	- rsx leather: 3
# 	- rl 3.5 5l awd rlx: 3
# 	- rl 3.5: 3
# 	- 3.5rl: 3
# 	- rlx base: 2
# 	- rlx sedan w/technology pk: 2
# 	- cl 3.0: 2
# 	- rlx 4dr sdn: 2
# 	- slx: 2
# 	- rlx tech pkg: 2
# 	- nsx-t: 2
# 	- rl awd: 2
# 	- integra gs: 2
# 	- rsx type s: 2
# 	- 3.5 rl: 2
# 	- rlx technology pkg sedan: 2
# 	- zdx: 2
# 	- legend: 2
# 	- nsx 5-spd open top: 2
# 	- rsx type-s: 2
# 	- rsx coupe 2.0l automatic leather moon sport wheels: 1
# 	- civic: 1
# 	- cl 3.2 type s: 1
# 	- 3.2 tl- type s: 1
# 	- rl sedan 4d: 1
# 	- tl-s: 1
# 	- rlx adance: 1
# 	- zdm: 1
# 	- cl type-s: 1
# 	- md-x awd: 1
# 	- cl 2.3: 1
# ...

# %%
# find all the unique value of model column given manufacturer column=acura and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

acura_models_with_counts = df[df['manufacturer'] == 'acura']['model'].value_counts()
models_to_drop = acura_models_with_counts[acura_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# for chrysler

# %%
#find all the unique value of model column given manufacturer column='chrysler' from df dataframe

chrysler_models_with_counts = df[df['manufacturer'] == 'chrysler']['model'].value_counts()
print(chrysler_models_with_counts)
# Out:
# outback     2236
# forester    1986
# impreza     1719
# legacy      1116
# Name: model, dtype: int64

# %%
#changing the cars' submodels into a general model.
df.loc[df['manufacturer'] == 'chrysler', 'model'] = df.loc[df['manufacturer'] == 'chrysler', 'model'].apply(lambda x: 'g-class' if isinstance(x, str) and 'glk' in x else x)

# %%
# find all the unique value of model column given manufacturer column=volkswagen and also print the frequency

chrysler_models = df[df['manufacturer'] == 'chrysler']['model'].unique()
chrysler_models_with_counts = df[df['manufacturer'] == 'chrysler']['model'].value_counts()
print("Unique models of chrysler and their frequency:")
for model, count in chrysler_models_with_counts.items():
    print(f"\t- {model}: {count}")

# %%
# find all the unique value of model column given manufacturer column=chrysler and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

chrysler_models_with_counts = df[df['manufacturer'] == 'chrysler']['model'].value_counts()
models_to_drop = chrysler_models_with_counts[chrysler_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# for buick

# %%
#find all the unique value of model column given manufacturer column='buick' from df dataframe

buick_models_with_counts = df[df['manufacturer'] == 'buick']['model'].value_counts()
print(buick_models_with_counts)

# %%
#changing the cars' submodels into a general model.
df.loc[df['manufacturer'] == 'buick', 'model'] = df.loc[df['manufacturer'] == 'buick', 'model'].apply(lambda x: 'g-class' if isinstance(x, str) and 'glk' in x else x)

# %%
# find all the unique value of model column given manufacturer column=buick and also print the frequency

buick_models = df[df['manufacturer'] == 'buick']['model'].unique()
buick_models_with_counts = df[df['manufacturer'] == 'buick']['model'].value_counts()
print("Unique models of buick and their frequency:")
for model, count in buick_models_with_counts.items():
    print(f"\t- {model}: {count}")

# %%
# find all the unique value of model column given manufacturer column=buick and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

buick_models_with_counts = df[df['manufacturer'] == 'buick']['model'].value_counts()
models_to_drop = buick_models_with_counts[buick_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# for mazda

# %%
#find all the unique value of model column given manufacturer column='mazda' from df dataframe

mazda_models_with_counts = df[df['manufacturer'] == 'mazda']['model'].value_counts()
print(mazda_models_with_counts)

# %%
#changing the cars' submodels into a general model.
df.loc[df['manufacturer'] == 'mazda', 'model'] = df.loc[df['manufacturer'] == 'mazda', 'model'].apply(lambda x: 'g-class' if isinstance(x, str) and 'glk' in x else x)

# %%
# find all the unique value of model column given manufacturer column=mazda and also print the frequency
mazda_models = df[df['manufacturer'] == 'mazda']['model'].unique()
mazda_models_with_counts = df[df['manufacturer'] == 'mazda']['model'].value_counts()
print("Unique models of mazda and their frequency:")
for model, count in mazda_models_with_counts.items():
    print(f"\t- {model}: {count}")

# %%
# find all the unique value of model column given manufacturer column=mazda and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

mazda_models_with_counts = df[df['manufacturer'] == 'mazda']['model'].value_counts()
models_to_drop = mazda_models_with_counts[mazda_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# infiniti

# %%
#find all the unique value of model column given manufacturer column='infiniti' from df dataframe

infiniti_models_with_counts = df[df['manufacturer'] == 'infiniti']['model'].value_counts()
print(infiniti_models_with_counts)

# %%
#changing the cars' submodels into a general model.
df.loc[df['manufacturer'] == 'infiniti', 'model'] = df.loc[df['manufacturer'] == 'infiniti', 'model'].apply(lambda x: 'g-class' if isinstance(x, str) and 'glk' in x else x)

# %%
# find all the unique value of model column given manufacturer column=infiniti and also print the frequency

infiniti_models = df[df['manufacturer'] == 'infiniti']['model'].unique()
infiniti_models_with_counts = df[df['manufacturer'] == 'infiniti']['model'].value_counts()
print("Unique models of infiniti and their frequency:")
for model, count in infiniti_models_with_counts.items():
    print(f"\t- {model}: {count}")

# %%
# find all the unique value of model column given manufacturer column=infiniti and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

infiniti_models_with_counts = df[df['manufacturer'] == 'infiniti']['model'].value_counts()
models_to_drop = infiniti_models_with_counts[infiniti_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# lincoln

# %%
#find all the unique value of model column given manufacturer column='subaru' from df dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print(subaru_models_with_counts).

# %%
#changing the cars' submodels into a general model.
df.loc[df['manufacturer'] == 'volkswagen', 'model'] = df.loc[df['manufacturer'] == 'volkswagen', 'model'].apply(lambda x: 'g-class' if isinstance(x, str) and 'glk' in x else x)

# %%
# find all the unique value of model column given manufacturer column=volkswagen and also print the frequency

subaru_models = df[df['manufacturer'] == 'subaru']['model'].unique()
subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print("Unique models of dodge and their frequency:")
for model, count in subaru_models_with_counts.items():
    print(f"\t- {model}: {count}")

# %%
# find all the unique value of model column given manufacturer column=volkswagen and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
models_to_drop = subaru_models_with_counts[subaru_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# volvo

# %%
#find all the unique value of model column given manufacturer column='subaru' from df dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print(subaru_models_with_counts)

# %%
#changing the cars' submodels into a general model.
df.loc[df['manufacturer'] == 'volkswagen', 'model'] = df.loc[df['manufacturer'] == 'volkswagen', 'model'].apply(lambda x: 'g-class' if isinstance(x, str) and 'glk' in x else x)

# %%
# find all the unique value of model column given manufacturer column=volkswagen and also print the frequency

subaru_models = df[df['manufacturer'] == 'subaru']['model'].unique()
subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print("Unique models of dodge and their frequency:")
for model, count in subaru_models_with_counts.items():
    print(f"\t- {model}: {count}")

# %%
# find all the unique value of model column given manufacturer column=volkswagen and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
models_to_drop = subaru_models_with_counts[subaru_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# mitsubishi

# %%
#find all the unique value of model column given manufacturer column='subaru' from df dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print(subaru_models_with_counts)

# %%
#changing the cars' submodels into a general model.
df.loc[df['manufacturer'] == 'volkswagen', 'model'] = df.loc[df['manufacturer'] == 'volkswagen', 'model'].apply(lambda x: 'g-class' if isinstance(x, str) and 'glk' in x else x)

# %%
# find all the unique value of model column given manufacturer column=volkswagen and also print the frequency

subaru_models = df[df['manufacturer'] == 'subaru']['model'].unique()
subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print("Unique models of dodge and their frequency:")
for model, count in subaru_models_with_counts.items():
    print(f"\t- {model}: {count}")

# %%
# find all the unique value of model column given manufacturer column=volkswagen and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
models_to_drop = subaru_models_with_counts[subaru_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# mini

# %%
#find all the unique value of model column given manufacturer column='subaru' from df dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print(subaru_models_with_counts)

# %%
#changing the cars' submodels into a general model.
df.loc[df['manufacturer'] == 'volkswagen', 'model'] = df.loc[df['manufacturer'] == 'volkswagen', 'model'].apply(lambda x: 'g-class' if isinstance(x, str) and 'glk' in x else x)

# %%
# find all the unique value of model column given manufacturer column=volkswagen and also print the frequency

subaru_models = df[df['manufacturer'] == 'subaru']['model'].unique()
subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print("Unique models of dodge and their frequency:")
for model, count in subaru_models_with_counts.items():
    print(f"\t- {model}: {count}")

# %%
# find all the unique value of model column given manufacturer column=volkswagen and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
models_to_drop = subaru_models_with_counts[subaru_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# pontiac

# %%
#find all the unique value of model column given manufacturer column='subaru' from df dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print(subaru_models_with_counts)

# %%
#changing the cars' submodels into a general model.
df.loc[df['manufacturer'] == 'volkswagen', 'model'] = df.loc[df['manufacturer'] == 'volkswagen', 'model'].apply(lambda x: 'g-class' if isinstance(x, str) and 'glk' in x else x)

# %%
# find all the unique value of model column given manufacturer column=volkswagen and also print the frequency

subaru_models = df[df['manufacturer'] == 'subaru']['model'].unique()
subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print("Unique models of dodge and their frequency:")
for model, count in subaru_models_with_counts.items():
    print(f"\t- {model}: {count}")

# %%
# find all the unique value of model column given manufacturer column=volkswagen and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
models_to_drop = subaru_models_with_counts[subaru_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# jaguar

# %%
#find all the unique value of model column given manufacturer column='subaru' from df dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print(subaru_models_with_counts)

# %%
#changing the cars' submodels into a general model.
df.loc[df['manufacturer'] == 'volkswagen', 'model'] = df.loc[df['manufacturer'] == 'volkswagen', 'model'].apply(lambda x: 'g-class' if isinstance(x, str) and 'glk' in x else x)

# %%
# find all the unique value of model column given manufacturer column=volkswagen and also print the frequency

subaru_models = df[df['manufacturer'] == 'subaru']['model'].unique()
subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print("Unique models of dodge and their frequency:")
for model, count in subaru_models_with_counts.items():
    print(f"\t- {model}: {count}")

# %%
# find all the unique value of model column given manufacturer column=volkswagen and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
models_to_drop = subaru_models_with_counts[subaru_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# rover

# %%
#find all the unique value of model column given manufacturer column='subaru' from df dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print(subaru_models_with_counts)

# %%
#changing the cars' submodels into a general model.
df.loc[df['manufacturer'] == 'volkswagen', 'model'] = df.loc[df['manufacturer'] == 'volkswagen', 'model'].apply(lambda x: 'g-class' if isinstance(x, str) and 'glk' in x else x)

# %%
# find all the unique value of model column given manufacturer column=volkswagen and also print the frequency

subaru_models = df[df['manufacturer'] == 'subaru']['model'].unique()
subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print("Unique models of dodge and their frequency:")
for model, count in subaru_models_with_counts.items():
    print(f"\t- {model}: {count}")

# %%
# find all the unique value of model column given manufacturer column=volkswagen and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
models_to_drop = subaru_models_with_counts[subaru_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# porsche

# %%
#find all the unique value of model column given manufacturer column='subaru' from df dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print(subaru_models_with_counts)

# %%
#changing the cars' submodels into a general model.
df.loc[df['manufacturer'] == 'volkswagen', 'model'] = df.loc[df['manufacturer'] == 'volkswagen', 'model'].apply(lambda x: 'g-class' if isinstance(x, str) and 'glk' in x else x)

# %%
# find all the unique value of model column given manufacturer column=volkswagen and also print the frequency

subaru_models = df[df['manufacturer'] == 'subaru']['model'].unique()
subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print("Unique models of dodge and their frequency:")
for model, count in subaru_models_with_counts.items():
    print(f"\t- {model}: {count}")

# %%
# find all the unique value of model column given manufacturer column=volkswagen and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
models_to_drop = subaru_models_with_counts[subaru_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# saturn

# %%
#find all the unique value of model column given manufacturer column='subaru' from df dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print(subaru_models_with_counts)

# %%
#changing the cars' submodels into a general model.
df.loc[df['manufacturer'] == 'volkswagen', 'model'] = df.loc[df['manufacturer'] == 'volkswagen', 'model'].apply(lambda x: 'g-class' if isinstance(x, str) and 'glk' in x else x)

# %%
# find all the unique value of model column given manufacturer column=volkswagen and also print the frequency

subaru_models = df[df['manufacturer'] == 'subaru']['model'].unique()
subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print("Unique models of dodge and their frequency:")
for model, count in subaru_models_with_counts.items():
    print(f"\t- {model}: {count}")

# %%
# find all the unique value of model column given manufacturer column=volkswagen and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
models_to_drop = subaru_models_with_counts[subaru_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# mercury

# %%
#find all the unique value of model column given manufacturer column='subaru' from df dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print(subaru_models_with_counts)

# %%
#changing the cars' submodels into a general model.
df.loc[df['manufacturer'] == 'volkswagen', 'model'] = df.loc[df['manufacturer'] == 'volkswagen', 'model'].apply(lambda x: 'g-class' if isinstance(x, str) and 'glk' in x else x)

# %%
# find all the unique value of model column given manufacturer column=volkswagen and also print the frequency

subaru_models = df[df['manufacturer'] == 'subaru']['model'].unique()
subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print("Unique models of dodge and their frequency:")
for model, count in subaru_models_with_counts.items():
    print(f"\t- {model}: {count}")

# %%
# find all the unique value of model column given manufacturer column=volkswagen and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
models_to_drop = subaru_models_with_counts[subaru_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# alfa-romeo

# %%
#find all the unique value of model column given manufacturer column='subaru' from df dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print(subaru_models_with_counts)

# %%
#changing the cars' submodels into a general model.
df.loc[df['manufacturer'] == 'volkswagen', 'model'] = df.loc[df['manufacturer'] == 'volkswagen', 'model'].apply(lambda x: 'g-class' if isinstance(x, str) and 'glk' in x else x)

# %%
# find all the unique value of model column given manufacturer column=volkswagen and also print the frequency

subaru_models = df[df['manufacturer'] == 'subaru']['model'].unique()
subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print("Unique models of dodge and their frequency:")
for model, count in subaru_models_with_counts.items():
    print(f"\t- {model}: {count}")

# %%
# find all the unique value of model column given manufacturer column=volkswagen and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
models_to_drop = subaru_models_with_counts[subaru_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# tesla

# %%
#find all the unique value of model column given manufacturer column='subaru' from df dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print(subaru_models_with_counts)

# %%
#changing the cars' submodels into a general model.
df.loc[df['manufacturer'] == 'volkswagen', 'model'] = df.loc[df['manufacturer'] == 'volkswagen', 'model'].apply(lambda x: 'g-class' if isinstance(x, str) and 'glk' in x else x)

# %%
# find all the unique value of model column given manufacturer column=volkswagen and also print the frequency

subaru_models = df[df['manufacturer'] == 'subaru']['model'].unique()
subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print("Unique models of dodge and their frequency:")
for model, count in subaru_models_with_counts.items():
    print(f"\t- {model}: {count}")

# %%
# find all the unique value of model column given manufacturer column=volkswagen and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
models_to_drop = subaru_models_with_counts[subaru_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %% [markdown]
# fiat

# %%
#find all the unique value of model column given manufacturer column='subaru' from df dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print(subaru_models_with_counts)


#changing the cars' submodels into a general model.
df.loc[df['manufacturer'] == 'volkswagen', 'model'] = df.loc[df['manufacturer'] == 'volkswagen', 'model'].apply(lambda x: 'g-class' if isinstance(x, str) and 'glk' in x else x)

# find all the unique value of model column given manufacturer column=volkswagen and also print the frequency

subaru_models = df[df['manufacturer'] == 'subaru']['model'].unique()
subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
print("Unique models of dodge and their frequency:")
for model, count in subaru_models_with_counts.items():
    print(f"\t- {model}: {count}")

# %%
# find all the unique value of model column given manufacturer column=volkswagen and its frequency. for all the items with frequency less than 1000. drop the record from 'df' dataframe

subaru_models_with_counts = df[df['manufacturer'] == 'subaru']['model'].value_counts()
models_to_drop = subaru_models_with_counts[subaru_models_with_counts < 1000].index.tolist()
df = df[~df['model'].isin(models_to_drop)]

# %%
# @title cylinders vs fuel

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['fuel'].value_counts()
    for x_label, grp in df_civic.groupby('cylinders')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('cylinders')
_ = plt.ylabel('fuel')

# %%
df.head(100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3e4443acfcdb> in <cell line: 1>()
# ----> 1 df.head(100)
#
# NameError: name 'df' is not defined

# %%
df.shape
# Out:
# (334914, 17)

# %%
# prompt: code to overide dataframe in  previous csv file

df.to_csv('cars.csv', index=False)

# %%
df.head()
# Out:
#    price    year manufacturer                 model  condition    cylinders  \
# 0  33590  2014.0          gmc                sierra       good  8 cylinders
# 1  22590  2010.0    chevrolet             silverado       good  8 cylinders
# 2  39590  2020.0    chevrolet             silverado       good  8 cylinders
# 3  30990  2017.0       toyota  tundra double cab sr       good  8 cylinders
# 4  15000  2013.0         ford             f-150 xlt  excellent  6 cylinders
#
#   fuel  odometer title_status transmission drive       size    type  \
# 0  gas   57923.0        clean        other   NaN        NaN  pickup
# 1  gas   71229.0        clean        other   NaN        NaN  pickup
# 2  gas   19160.0        clean        other   NaN        NaN  pickup
# 3  gas   41124.0        clean        other   NaN        NaN  pickup
# 4  gas  128000.0        clean    automatic   rwd  full-size   truck
#
#   paint_color state     lat     long
# 0       white    al  32.590 -85.4800
# ...

# %%
# prompt: how to save dataframe in  a csv file

df.to_csv('cars4.csv', index=False)

# %%
df.tail(25)
# Out:
#         price    year   manufacturer                      model condition  \
# 316458   6577  2013.0        hyundai                    elantra       NaN
# 316460   4977  2005.0         nissan                     altima       NaN
# 316461   7977  2009.0         toyota                     matrix       NaN
# 316462   5477  2003.0         nissan                     murano       NaN
# 316463  41990  2019.0         toyota      4runner limited sport      good
# 316464  51990  2020.0       cadillac                        xts      good
# 316465  48590  2020.0       cadillac                        xts      good
# 316466  39990  2017.0       infiniti      qx80 sport utility 4d      good
# 316467  30990  2019.0     alfa-romeo   romeo giulia ti sedan 4d      good
# 316468  27590  2018.0            NaN   Genesis G80 3.8 Sedan 4D      good
# 316469  25590  2017.0            NaN   Genesis G80 3.8 Sedan 4D      good
# 316470  29590  2016.0         toyota  4runner sr5 sport utility      good
# ...
